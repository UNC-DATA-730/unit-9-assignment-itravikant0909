# %% [markdown]
# **Relevant reading for this problem set**:
# <a href="https://moderndive.com/9-hypothesis-testing.html"
# target="_blank">ModernDive Chapter 9: Hypothesis Testing</a>.

# %% [markdown]
# First load the necessary packages:

# %%
library('tidyverse')
library('infer')
library('dplyr')

# %% [markdown]
# For this Problem Set you will work with some grade-point-average (GPA)
# data for college freshman. The following will read in the data:

# %%
sat_gpa = read_csv("https://rudeboybert.github.io/SDS220/static/PS/sat_gpa.csv", col_types = cols(), col_select = c(-1))

sat_gpa |> glimpse()
# Out:
# New names:
# • `` -> `...1`
# Rows: 1,000
# Columns: 6
# $ sex        <chr> "Male", "Female", "Female", "Male", "Male", "Female", "Male…
# $ sat_verbal <dbl> 65, 58, 56, 42, 55, 55, 57, 53, 67, 41, 58, 45, 43, 50, 54,…
# $ sat_math   <dbl> 62, 64, 60, 53, 52, 56, 65, 62, 77, 44, 70, 57, 45, 58, 66,…
# $ sat_total  <dbl> 127, 122, 116, 95, 107, 111, 122, 115, 144, 85, 128, 102, 8…
# $ gpa_hs     <chr> "high", "high", "high", "high", "high", "high", "low", "hig…
# $ gpa_fy     <dbl> 3.18, 3.33, 3.25, 2.42, 2.63, 2.91, 2.83, 2.51, 3.82, 2.54,…

# %% [markdown]
# Each row or case in this data frame is a student. The data includes:
#
# -   the (binary) gender of each student
# -   the math, verbal and total SAT scores for each student
# -   the GPA range of each student in high school (categorized as “low”
#     or “high”)
# -   the GPA of each student their first year of college on a numeric
#     scale.
#
# We will use hypothesis testing to answer the following questions:
#
# 1.  Is there a difference in male and female freshman GPAs?
# 2.  Is there a difference in total SAT score for students with a “low”
#     and “high” high-school GPA?
#
# Note, if you get stuck as you are working through this, it will be
# helpful to review Chapter 9 in ModernDive.

# %% [markdown]
# ## Question 1: Gender differences in first-year GPA?
#
# For this question, let’s use a pre-determined $\alpha$
# significance-level of 0.05.

# %% [markdown]
# ## Q1.a)
#
# Calculate the mean GPA score for each gender, using the `group_by` and
# `summarize` commands from the `dplyr` package.

# %%
# Group by gender and calculate mean GPA for each gender
mean_gpa_by_gender <- sat_gpa %>%
  group_by(sex) %>%
  summarize(mean_gpa = mean(gpa_fy, na.rm = TRUE))

# Print the result
print(mean_gpa_by_gender)
# Out:
# # A tibble: 2 × 2
#   sex    mean_gpa
#   <chr>     <dbl>
# 1 Female     2.54
# 2 Male       2.40

# %% [markdown]
# **Questions**:
#
# 1.  What is the difference in sample mean GPA’s?
# 2.  Make a guess: is this difference statistically significant?
#
# **Answers**:
#
# 1.
# The mean GPA for females is 2.54, while for males, it is 2.40.
# The difference in sample mean GPA is: 2.54 − 2.40 = 0.14
# 2.54−2.40=0.14
# 2.  The difference is relatively small (0.14), and while it could be significant, statistical significance depends on factors like the sample size and the variability of GPAs within each group.

# %% [markdown]
# ## Q1.b)
#
# Generate a data visualization that displays the GPAs of the two groups.
# Be sure to include a title and label your axes.

# %%
# Load necessary library
library('ggplot2')

# Plotting GPA by gender
ggplot(sat_gpa, aes(x = sex, y = gpa_fy, fill = sex)) +
  geom_boxplot() +
  labs(title = "First-Year GPA by Gender", x = "Gender", y = "First-Year GPA") +
  theme_minimal() +
  theme(legend.position = "none")
# Out:
# plot without title

# %% [markdown]
# ## Stating a null hypothesis
#
# We will now test the null hypothesis that there’s no difference in
# population mean GPA between the genders at the population level. We can
# write this out in mathematical notation
#
# $$\begin{aligned} H_0:&\mu_{female} = \mu_{male} \\\ \mbox{vs }H_A:& \mu_{female} \neq \mu_{male} \end{aligned}$$
#
# or expressed differently, that the difference is 0 or not:
#
# $$\begin{aligned} H_0:&\mu_{female} - \mu_{male} = 0 \\\ \mbox{vs }H_A:& \mu_{female} - \mu_{male} \neq 0 \end{aligned}$$
#
# ## Testing the hypothesis
#
# Here’s how we use the `infer` package to conduct this hypothesis test:
#
# ### Step 1: Calculate the observed difference
#
# Note that the order we choose does not matter here (female then
# male)…but since we used `order = c("Female", "Male")` here, we should do
# the same in subsequent calculations!

# %%
obs_diff_gpa_sex = sat_gpa |>
  specify(gpa_fy ~ sex) |>
  calculate(stat = "diff in means", order = c("Female", "Male"))

obs_diff_gpa_sex
# Out:
#   stat
# 1 0.1485209

# %% [markdown]
# Note that this is the difference in the group means we calculated
# earlier!

# %%
2.54−2.40=0.14

# %% [markdown]
# ### Step 2. Generate the null distribution of $\delta$
#
# This step involves generating simulated values *as if* we lived in a
# world where there’s no difference between the two groups. Going back to
# the idea of permutation, and tactile sampling, this is akin to shuffling
# the GPA scores between male and female labels (i.e. removing the
# structure to the data) just as we could have done with index cards.

# %%
gpas_in_null_world = sat_gpa |> 
  specify(gpa_fy ~ sex) |> 
  hypothesize(null = "independence") |>
  generate(reps = 5000, type = 'permute')

gpas_in_null_world |> head()
# Out:
#   gpa_fy sex    replicate
# 1 2.80   Male   1
# 2 3.06   Female 1
# 3 3.41   Female 1
# 4 3.35   Male   1
# 5 2.60   Male   1
# 6 1.77   Female 1

# %% [markdown]
# ## Q1.c)
#
# **Question**:
#
# 1.  What was the size of the “shuffled” (permuted) sample in each run?
# 2.  How many times did we “shuffle” (permute) the sample? How many rows
#     are in the `gpas_in_null_world` data frame?
#
# **Answer:**
#
# 1.  5,000,000 sample size
# 2.  we have shuffled 1000 rows 5000 times. resulting 5 million rows

# %% [markdown]
# ### Step 3. Calculate the differences between male and females under the null
#
# The following calculates the differences in mean GPA for males and
# females for “shuffled” (permuted) data.

# %%
gpa_diff_under_null = gpas_in_null_world |>
  calculate(stat = "diff in means", order = c("Female", "Male")) 

gpa_diff_under_null |> 
  head()
# Out:
#   replicate stat
# 1 1         -0.041874079
# 2 2         -0.000551765
# 3 3          0.027557018
# 4 4         -0.039231373
# 5 5         -0.039952111
# 6 6          0.004773688

# %% [raw]
# ## Q1.d)
#
# **Question**:
#
# 1.  How many rows are in this data frame? Why?
#
# **Answer:**
#
# 1.  Difference in mean has been calculated for every rep that is 5000 rows

# %% [markdown]
# ### Step 4. Visualize how the observed difference compares to the null distribution of $\delta$
#
# The following plots the $\delta$ values we calculated for each of the
# different “shuffled” replicates. This is the null distribution of
# $\delta$. The red line shows the observed difference between male and
# female scores in the data (-0.1485209) from step 1.

# %%
visualize(gpa_diff_under_null) +
  shade_p_value(obs_stat = obs_diff_gpa_sex, direction = "both") +
  labs(x = "Difference in mean GPA for males and females", y = "Count",
       title = "Null distribution of differences in male and female GPAs",
       subtitle = "Actual difference observed in the data is marked in red"
       )
# Out:
# plot without title

# %% [markdown]
# **Note that zero is the center of this null distribution.** The null
# hypothesis is that there is no difference between males and females in
# GPA score. In the permutations, zero was the most common difference,
# because observed GPA values were re-assigned to males and females **at
# random**. Differences as large as \~ 0.1 and -0.1 occurred, but much
# less frequently, because they are just not as likely when structure is
# removed from the data.
#
# ### Step 5: Calculate a p-value

# %%
gpa_diff_under_null %>% 
  get_pvalue(obs_stat = obs_diff_gpa_sex, direction = "both")
# Out:
#   p_value
# 1 0.0016

# %% [markdown]
# This result indicates that there is a 0.1% chance (very low) chance that
# we would see a difference of 0.15 in GPA scores between males and
# females (or a bigger difference) if in fact there was truly no
# difference between the sexes in GPA scores in the population.

# %% [markdown]
# ## Q1.e)
#
# Fill in the blanks below to write up the results & conclusions for this
# test:
#
# The mean GPA scores for females in our sample ($\bar{x}$ = \_\_\_\_\_\_)
# was greater than that of males ($\bar{x}$ = \_\_\_\_\_\_). This
# difference **(was/was not)**\_ statistically significant at
# $\alpha = 0.05$, (p = \_\_\_\_\_\_\_). Given this I **(would/would
# not)** reject the Null hypothesis and conclude that \_\_\_\_\_ have
# higher GPAs than \_\_\_\_\_ at the population level.

# %% [markdown]
# ### Step 6: Calculate a confidence interval for the difference
#
# The following will allow us to calculate a 95% confidence interval for
# the difference between mean GPA scores for males and females.

# %%
ci_diff_gpa_means <- sat_gpa %>% 
  specify(gpa_fy ~ sex) %>%
  generate(reps = 5000, type = "bootstrap") %>% 
  calculate(stat = "diff in means", order = c("Female", "Male")) %>% 
  get_confidence_interval(level = 0.95)

ci_diff_gpa_means
# Out:
#   lower_ci  upper_ci
# 1 0.0538075 0.240559

# %% [markdown]
# ## Complete all the above tasks with a t-test
#
# Note that all the above steps can be done with one line of code **if a
# slew of assumptions** like normality and equal variance of the groups
# are met.

# %%
t.test(gpa_fy ~ sex, var.equal = TRUE, data = sat_gpa)
# Out:
# 	Two Sample t-test
#
# data:  gpa_fy by sex
# t = 3.1828, df = 998, p-value = 0.001504
# alternative hypothesis: true difference in means between group Female and group Male is not equal to 0
# 95 percent confidence interval:
#  0.05695029 0.24009148
# sample estimates:
# mean in group Female   mean in group Male
#             2.544587             2.396066

# %% [markdown]
# ## Question 2: Relationship between high-school GPA category and Total SAT score?
#
# For this analysis `sat_total` is the outcome variable, and `gpa_hs` is
# the predictor variable, with two levels “low” and “high”. For this
# question, let’s use a pre-determined $\alpha$ significance-level of
# 0.10, which is considered a more liberal significance-level than 0.05
# since p-values will have an easier time being less than $\alpha$, and
# thus we are likely to reject the null hypothesis $H_0$ more often.
#
# ## Exploratory data analysis
#
# We can first calculate the mean total SAT score for each group (i.e
# students with a low and high GPA), using the `group_by` and `summarize`
# commands from the `dplyr` package.

# %%
avg_sat_gpa <- sat_gpa %>% 
  group_by(gpa_hs) %>% 
  summarize(sat_total = mean(sat_total))

avg_sat_gpa
# Out:
#   gpa_hs sat_total
# 1 high   108.67828
# 2 low     98.23047

# %% [markdown]
# We will next generate a data visualization that displays the total SAT
# scores of the two groups. Be sure to include a title and label your
# axes.

# %%
ggplot(sat_gpa, aes(x = gpa_hs, y = sat_total)) + 
    geom_point(fill = "darkgreen", position = position_jitter(height = 0, width = 0.2), alpha = 0.5, color = 'steelblue') + 
    stat_summary(geom = 'crossbar', fun = median, color = 'firebrick', size = 0.25, alpha = 0.6) +
    labs(title = "SAT scores based on high school GPA scores", 
       x = "GPA ranking", y = "SAT score")
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %% [markdown]
# ## Stating a null hypothesis

# %% [markdown]
# ## Q2.a)
#
# State the null hypothesis that you are testing (using either words or
# symbols)
#
# **Answer:**
#
# 1.  The null hypothesis states that there is no difference in the mean GPA scores between male and female students in the population.

# %% [markdown]
# ## Testing the hypothesis

# %% [markdown]
# ## Q2.b)
#
# Calculate the observed difference between the mean total SAT scores of
# the low and high GPA high-school students.

# %%
# you finish this code....
low_gpa_threshold <- 3.0

obs_diff_sat_hs_gpa <- sat_gpa %>%
  mutate(gpa_category = ifelse(gpa_fy < low_gpa_threshold, "Low", "High")) %>%
  group_by(gpa_category) %>%
  summarize(mean_sat = mean(sat_score, na.rm = TRUE)) %>%
  spread(gpa_category, mean_sat) %>%
  mutate(observed_difference = High - Low)

# Display the observed difference
obs_diff_sat_hs_gpa
# Out:
# Error in `summarize()`:
# ℹ In argument: `mean_sat = mean(sat_score, na.rm = TRUE)`.
# ℹ In group 1: `gpa_category = "High"`.
# Caused by error:
# ! object 'sat_score' not found
# Traceback:
#
# 1. sat_gpa %>% mutate(gpa_category = ifelse(gpa_fy < low_gpa_threshold,
#  .     "Low", "High")) %>% group_by(gpa_category) %>% summarize(mean_sat = mean(sat_score,
#  .     na.rm = TRUE)) %>% spread(gpa_category, mean_sat) %>% mutate(observed_difference = High -
#  .     Low)
# 2. mutate(., observed_difference = High - Low)
# 3. spread(., gpa_category, mean_sat)
# 4. summarize(., mean_sat = mean(sat_score, na.rm = TRUE))
# 5. summarise.grouped_df(., mean_sat = mean(sat_score, na.rm = TRUE))
# 6. summarise_cols(.data, dplyr_quosures(...), by, "summarise")
# 7. withCallingHandlers({
#  .     for (i in seq_along(dots)) {
#  .         poke_error_context(dots, i, mask = mask)
#  .         context_poke("column", old_current_column)
#  .         dot <- dots[[i]]
#  .         dot <- expand_pick(dot, mask)
#  .         quosures <- expand_across(dot)
#  .         quosures_results <- map(quosures, summarise_eval_one,
#  .             mask = mask)
#  .         for (k in seq_along(quosures)) {
#  .             quo <- quosures[[k]]
#  .             quo_data <- attr(quo, "dplyr:::data")
#  .             quo_result <- quosures_results[[k]]
#  .             if (is.null(quo_result)) {
#  .                 next
#  .             }
#  .             types_k <- quo_result$types
#  .             chunks_k <- quo_result$chunks
#  .             results_k <- quo_result$results
#  .             if (!quo_data$is_named && is.data.frame(types_k)) {
#  .                 chunks_extracted <- .Call(dplyr_extract_chunks,
#  .                   chunks_k, types_k)
#  .                 types_k_names <- names(types_k)
#  .                 for (j in seq_along(chunks_extracted)) {
#  .                   mask$add_one(name = types_k_names[j], chunks = chunks_extracted[[j]],
#  .                     result = results_k[[j]])
#  .                 }
#  .                 chunks <- append(chunks, chunks_extracted)
#  .                 types <- append(types, as.list(types_k))
#  .                 results <- append(results, results_k)
#  .                 out_names <- c(out_names, types_k_names)
#  .             }
#  .             else {
#  .                 name <- dplyr_quosure_name(quo_data)
#  .                 mask$add_one(name = name, chunks = chunks_k,
#  .                   result = results_k)
#  .                 chunks <- append(chunks, list(chunks_k))
#  .                 types <- append(types, list(types_k))
#  .                 results <- append(results, list(results_k))
#  .                 out_names <- c(out_names, name)
#  .             }
#  .         }
#  .     }
#  .     sizes <- .Call(dplyr_summarise_recycle_chunks_in_place, chunks,
#  .         results)
#  .     for (i in seq_along(chunks)) {
#  .         result <- results[[i]] %||% vec_c(!!!chunks[[i]], .ptype = types[[i]])
#  .         cols[[out_names[i]]] <- result
#  .     }
#  . }, error = function(cnd) {
#  .     if (inherits(cnd, "dplyr:::summarise_incompatible_size")) {
#  .         action <- "recycle"
#  .         i <- cnd$dplyr_error_data$index
#  .     }
#  .     else {
#  .         action <- "compute"
#  .         i <- i
#  .     }
#  .     handler <- dplyr_error_handler(dots = dots, mask = mask,
#  .         bullets = summarise_bullets, error_call = error_call,
#  .         action = action)
#  .     handler(cnd)
#  . }, warning = dplyr_warning_handler(state = warnings_state, mask = mask,
#  .     error_call = error_call))
# 8. map(quosures, summarise_eval_one, mask = mask)
# 9. lapply(.x, .f, ...)
# 10. FUN(X[[i]], ...)
# 11. mask$eval_all_summarise(quo)
# 12. eval()
# 13. mean(sat_score, na.rm = TRUE)
# 14. .handleSimpleError(function (cnd)
#   . {
#   .     if (inherits(cnd, "dplyr:::summarise_incompatible_size")) {
#   .         action <- "recycle"
#   .         i <- cnd$dplyr_error_data$index
#   .     }
#   .     else {
#   .         action <- "compute"
#   .         i <- i
#   .     }
#   .     handler <- dplyr_error_handler(dots = dots, mask = mask,
#   .         bullets = summarise_bullets, error_call = error_call,
#   .         action = action)
#   .     handler(cnd)
#   . }, "object 'sat_score' not found", base::quote(NULL))
# 15. h(simpleError(msg, call))
# 16. handler(cnd)
# 17. abort(message, class = error_class, parent = parent, call = error_call)
# 18. signal_abort(cnd, .file)

# %% [markdown]
# ## Q2.c)
#
# Generate the null distribution of $\delta$. Here you need to generate
# simulated values *as if* we lived in a world where there’s no difference
# in SAT scores between high school students with low and high GPAs.

# %%
# you finish this code....

# Define the GPA threshold
low_gpa_threshold <- 3.0

# Set the number of simulations for the null distribution (e.g., 1000)
n_simulations <- 1000

# Create the null distribution by shuffling SAT scores
set.seed(123)  # Set a seed for reproducibility

sat_in_null_world <- replicate(n_simulations, {
  # Shuffle SAT scores across all students
  shuffled_scores <- sample(sat_gpa$sat_score)
  
  # Assign shuffled scores back to the original data frame
  sat_gpa_shuffled <- sat_gpa %>%
    mutate(sat_score = shuffled_scores) %>%
    mutate(gpa_category = ifelse(gpa < low_gpa_threshold, "Low", "High")) %>%
    group_by(gpa_category) %>%
    summarize(mean_sat = mean(sat_score, na.rm = TRUE)) %>%
    spread(gpa_category, mean_sat) %>%
    mutate(observed_difference = High - Low) %>%
    pull(observed_difference)
  
  return(sat_gpa_shuffled)
})

# Convert the list to a vector
null_distribution <- unlist(sat_in_null_world)

# Inspect the null distribution
summary(null_distribution)
hist(null_distribution, main="Null Distribution of Observed Differences", xlab="Observed Difference")
# Out:
# Warning message:
# “Unknown or uninitialised column: `sat_score`.”
# Error in `mutate()`:
# ℹ In argument: `gpa_category = ifelse(gpa < low_gpa_threshold, "Low",
#   "High")`.
# Caused by error:
# ! object 'gpa' not found
# Traceback:
#
# 1. replicate(n_simulations, {
#  .     shuffled_scores <- sample(sat_gpa$sat_score)
#  .     sat_gpa_shuffled <- sat_gpa %>% mutate(sat_score = shuffled_scores) %>%
#  .         mutate(gpa_category = ifelse(gpa < low_gpa_threshold,
#  .             "Low", "High")) %>% group_by(gpa_category) %>% summarize(mean_sat = mean(sat_score,
#  .         na.rm = TRUE)) %>% spread(gpa_category, mean_sat) %>%
#  .         mutate(observed_difference = High - Low) %>% pull(observed_difference)
#  .     return(sat_gpa_shuffled)
#  . })
# 2. sapply(integer(n), eval.parent(substitute(function(...) expr)),
#  .     simplify = simplify)
# 3. lapply(X = X, FUN = FUN, ...)
# 4. FUN(X[[i]], ...)
# 5. sat_gpa %>% mutate(sat_score = shuffled_scores) %>% mutate(gpa_category = ifelse(gpa <
#  .     low_gpa_threshold, "Low", "High")) %>% group_by(gpa_category) %>%
#  .     summarize(mean_sat = mean(sat_score, na.rm = TRUE)) %>% spread(gpa_category,
#  .     mean_sat) %>% mutate(observed_difference = High - Low) %>%
#  .     pull(observed_difference)   # at line 17-24 of file <text>
# 6. pull(., observed_difference)
# 7. mutate(., observed_difference = High - Low)
# 8. spread(., gpa_category, mean_sat)
# 9. summarize(., mean_sat = mean(sat_score, na.rm = TRUE))
# 10. group_by(., gpa_category)
# 11. mutate(., gpa_category = ifelse(gpa < low_gpa_threshold, "Low",
#   .     "High"))
# 12. mutate.data.frame(., gpa_category = ifelse(gpa < low_gpa_threshold,
#   .     "Low", "High"))
# 13. mutate_cols(.data, dplyr_quosures(...), by)
# 14. withCallingHandlers(for (i in seq_along(dots)) {
#   .     poke_error_context(dots, i, mask = mask)
#   .     context_poke("column", old_current_column)
#   .     new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#   . }, error = dplyr_error_handler(dots = dots, mask = mask, bullets = mutate_bullets,
#   .     error_call = error_call, error_class = "dplyr:::mutate_error"),
#   .     warning = dplyr_warning_handler(state = warnings_state, mask = mask,
#   .         error_call = error_call))
# 15. mutate_col(dots[[i]], data, mask, new_columns)
# 16. mask$eval_all_mutate(quo)
# 17. eval()
# 18. ifelse(gpa < low_gpa_threshold, "Low", "High")
# 19. .handleSimpleError(function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . }, "object 'gpa' not found", base::quote(NULL))
# 20. h(simpleError(msg, call))
# 21. abort(message, class = error_class, parent = parent, call = error_call)
# 22. signal_abort(cnd, .file)

# %% [markdown]
# ## Q2.d)
#
# Calculate the differences in mean SAT scores between students with low
# and high GPA scores under the Null. Note…you should use whatever order
# you chose above…i.e. `order = c("low", "high")` or
# `order = c("high", "low")`.

# %%
# you finish this code....

# sat_diff_under_null <-
# Out:
# Warning message:
# “Unknown or uninitialised column: `sat_score`.”
# Error in `mutate()`:
# ℹ In argument: `gpa_category = ifelse(gpa < low_gpa_threshold, "Low",
#   "High")`.
# Caused by error:
# ! object 'gpa' not found
# Traceback:
#
# 1. sat_gpa %>% mutate(sat_score = shuffled_scores) %>% mutate(gpa_category = ifelse(gpa <
#  .     low_gpa_threshold, "Low", "High")) %>% group_by(gpa_category) %>%
#  .     summarize(mean_sat = mean(sat_score, na.rm = TRUE)) %>% mutate(gpa_category = factor(gpa_category,
#  .     levels = c("Low", "High"))) %>% arrange(gpa_category)
# 2. arrange(., gpa_category)
# 3. mutate(., gpa_category = factor(gpa_category, levels = c("Low",
#  .     "High")))
# 4. summarize(., mean_sat = mean(sat_score, na.rm = TRUE))
# 5. group_by(., gpa_category)
# 6. mutate(., gpa_category = ifelse(gpa < low_gpa_threshold, "Low",
#  .     "High"))
# 7. mutate.data.frame(., gpa_category = ifelse(gpa < low_gpa_threshold,
#  .     "Low", "High"))
# 8. mutate_cols(.data, dplyr_quosures(...), by)
# 9. withCallingHandlers(for (i in seq_along(dots)) {
#  .     poke_error_context(dots, i, mask = mask)
#  .     context_poke("column", old_current_column)
#  .     new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#  . }, error = dplyr_error_handler(dots = dots, mask = mask, bullets = mutate_bullets,
#  .     error_call = error_call, error_class = "dplyr:::mutate_error"),
#  .     warning = dplyr_warning_handler(state = warnings_state, mask = mask,
#  .         error_call = error_call))
# 10. mutate_col(dots[[i]], data, mask, new_columns)
# 11. mask$eval_all_mutate(quo)
# 12. eval()
# 13. ifelse(gpa < low_gpa_threshold, "Low", "High")
# 14. .handleSimpleError(function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . }, "object 'gpa' not found", base::quote(NULL))
# 15. h(simpleError(msg, call))
# 16. abort(message, class = error_class, parent = parent, call = error_call)
# 17. signal_abort(cnd, .file)

# %% [markdown]
# ## Q2.e)
#
# Visualize how the observed difference compares to the null distribution
# of $\delta$. Generate a histogram of the null distribution, with a
# vertical red line showing the observed difference in SAT scores between
# high school students with a high and low GPA.

# %%
# you finish this code....

# sat_diff_under_null %>%

# %% [markdown]
# ## Q2.f)
#
# Calculate a p-value

# %% [markdown]
# ## Q2.g)
#
# Write up the results & conclusions for this hypothesis test. Note,
# p-values less than 0.001 are often reported as p \< 0.001.
#
# **Answer:**
#
# 1.

# %% [markdown]
# ## Q2.h)
#
# Calculate a confidence interval for the difference in total SAT scores
# for students with high and low high-school GPA scores. Note…you should
# use whatever order you chose above…i.e. `order = c("low", "high")` or
# `order = c("high", "low")`.

# %%
# you finish this code....

# ci_diff_sat_means <- sat_gpa %>%

# %% [markdown]
# ## Q2.i)
#
# Use a t-test to test the null hypothesis that total SAT scores do not
# differ between students with high and low high school GPA scores at the
# population level.
